# %% [markdown]
# # Section 3.2 Single Model Visual Diagnostics

# %% [markdown]
# ## Exercise

# %%
import os
import arviz as az
NETCDF_DIR = "inference_data"

# %%
data = az.from_netcdf(os.path.join(NETCDF_DIR, "data_bad_init.nc"))
az.plot_autocorr(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe9b85f1320>,
# ...
#       dtype=object)

# %%
data_good_init = az.from_netcdf(os.path.join(NETCDF_DIR, "data_good_init.nc"))
az.plot_autocorr(data_good_init)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe95b451748>,
# ...
#       dtype=object)

# %%
az.plot_autocorr(data_good_init.posterior.sel(draw=slice(30, None)))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe95b275908>,
# ...
#       dtype=object)

# %%
data_good_init_long_chain = az.from_netcdf(os.path.join(NETCDF_DIR, "data_good_init_long_chain.nc"))
az.plot_autocorr(data_good_init_long_chain)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe95abc1cc0>,
# ...
#       dtype=object)

# %%
data_hmc = az.from_netcdf(os.path.join(NETCDF_DIR, "data_hmc.nc"))
az.plot_autocorr(data_hmc)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe95b20ce80>,
# ...
#       dtype=object)
