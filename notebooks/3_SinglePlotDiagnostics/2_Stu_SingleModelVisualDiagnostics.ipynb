# %% [markdown]
# # Section 3.2 Single Model Visual Diagnostics

# %%
import os
import arviz as az

# Change working directory
if os.path.split(os.getcwd())[-1] != "notebooks":
    os.chdir(os.path.join(".."))

NETCDF_DIR = "inference_data"

# %% [markdown]
# ## Activity: Plot Autocorrelation for our previous analysis
# Load and create Autocorrelation plots for each of the datasets. Discuss with your partner whether the results make sense or not. If needed compare to the traceplot to see how the two diagnostics compare

# %% [markdown]
# ### Exercise 1: data_bad_init.nc autocorrelation diagram

# %%
data = az.from_netcdf(os.path.join(NETCDF_DIR, "data_bad_init.nc"))
az.plot_autocorr(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f88c18f77b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88c18c17b8>]],
#       dtype=object)

# %% [markdown]
# ### Exercise 2: data_good_init.nc autocorrelation diagram

# %%
data_good_init = az.from_netcdf(os.path.join(NETCDF_DIR, "data_good_init.nc"))
az.plot_autocorr(data_good_init)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f88c0789470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88c0612d30>]],
#       dtype=object)

# %% [markdown]
# ### Exercise 3: data_good_init_long_chain.nc autocorrelation diagram

# %%
data_good_init_long_chain = az.from_netcdf(os.path.join(NETCDF_DIR, "data_good_init_long_chain.nc"))
az.plot_autocorr(data_good_init_long_chain)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f88c05934e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88c03b4a20>]],
#       dtype=object)

# %% [markdown]
# ### Exercise 4: data_tuned_mh.nc autocorrelation diagram

# %%
data_tuned_mh = az.from_netcdf(os.path.join(NETCDF_DIR, "data_tuned_mh.nc"))
az.plot_autocorr(data_tuned_mh)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f88c0333d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f88c0326898>]],
#       dtype=object)

# %% [markdown]
# ### Exercise 5: data_hmc.nc autocorrelation diagram

# %%
data_hmc = az.from_netcdf(os.path.join(NETCDF_DIR, "data_hmc.nc"))
az.plot_autocorr(data_hmc)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f88c0184be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f889838bbe0>]],
#       dtype=object)

# %% [markdown]
# ### Exercise 6: Discussion about Visual diagnostics
# Turn to your partner and discuss the results of the visual diagnostics.
# * Do the visual diagnostics correlate with your knowledge of MCMC theory?
# * What features of the trace plots and autocorrelation plots indicate a relative good MCMC run? Which ones indicate a relatively bad MCMC run?
